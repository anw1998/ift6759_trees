# %% [markdown]
# # Setup

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install laspy -q
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 30.4 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
#   Building wheel for laspy (pyproject.toml) ... done

# %%
# !pip install spectral
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting spectral
#   Downloading spectral-0.23.1-py3-none-any.whl (212 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 212.9/212.9 KB 9.3 MB/s eta 0:00:00
# Requirement already satisfied: numpy in /usr/local/lib/python3.9/dist-packages (from spectral) (1.22.4)
# Installing collected packages: spectral
# Successfully installed spectral-0.23.1

# %%
# !pip install rasterio -q
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 20.1/20.1 MB 24.5 MB/s eta 0:00:00

# %%
# !pip install Fiona -q

# %%
# !pip install mapclassify -q

# %%
# !pip install geopandas -q
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 22.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.0/16.0 MB 62.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.7/7.7 MB 76.7 MB/s eta 0:00:00

# %% [markdown]
# # Data Split
# 80% train, 10% validation, 10% test

# %% [markdown]
# ## Image split

# %%
import os
from glob import glob
from PIL import Image
import laspy
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits import mplot3d
import spectral
import cv2
from skimage import io

# %%
base_dir = '/content/drive/MyDrive/ift6759_trees/data/raw/RemoteSensing'

rgb_list = sorted(glob(os.path.join(base_dir, 'RGB', '*.tif')))
las_list = sorted(glob(os.path.join(base_dir, 'LAS', '*.las'))) # LiDAR
hsi_list = sorted(glob(os.path.join(base_dir, 'HSI', '*.tif'))) # Hyperspectral
chm_list = sorted(glob(os.path.join(base_dir, 'CHM', '*.tif'))) # Canopy Height Model

# %%
len(rgb_list), len(las_list), len(hsi_list), len(chm_list)
# Out:
# (85, 85, 85, 85)

# %%
import random
from random import sample

random.seed(0)
val_test = sample(rgb_list, 18)
val = val_test[:9]
test = val_test[9:]
train = [x for x in rgb_list if x not in val_test]

# %%
val
# Out:
# ['/content/drive/MyDrive/ift6759_trees/data/raw/RemoteSensing/RGB/OSBS_12.tif',
#  '/content/drive/MyDrive/ift6759_trees/data/raw/RemoteSensing/RGB/OSBS_16.tif',
#  '/content/drive/MyDrive/ift6759_trees/data/raw/RemoteSensing/RGB/MLBS_14.tif',
#  '/content/drive/MyDrive/ift6759_trees/data/raw/RemoteSensing/RGB/MLBS_4.tif',
#  '/content/drive/MyDrive/ift6759_trees/data/raw/RemoteSensing/RGB/OSBS_27.tif',
#  '/content/drive/MyDrive/ift6759_trees/data/raw/RemoteSensing/RGB/OSBS_24.tif',
#  '/content/drive/MyDrive/ift6759_trees/data/raw/RemoteSensing/RGB/OSBS_14.tif',
#  '/content/drive/MyDrive/ift6759_trees/data/raw/RemoteSensing/RGB/MLBS_44.tif',
#  '/content/drive/MyDrive/ift6759_trees/data/raw/RemoteSensing/RGB/OSBS_23.tif']

# %%
test
# Out:
# ['/content/drive/MyDrive/ift6759_trees/data/raw/RemoteSensing/RGB/MLBS_9.tif',
#  '/content/drive/MyDrive/ift6759_trees/data/raw/RemoteSensing/RGB/OSBS_35.tif',
#  '/content/drive/MyDrive/ift6759_trees/data/raw/RemoteSensing/RGB/MLBS_34.tif',
#  '/content/drive/MyDrive/ift6759_trees/data/raw/RemoteSensing/RGB/OSBS_26.tif',
#  '/content/drive/MyDrive/ift6759_trees/data/raw/RemoteSensing/RGB/MLBS_25.tif',
#  '/content/drive/MyDrive/ift6759_trees/data/raw/RemoteSensing/RGB/MLBS_42.tif',
#  '/content/drive/MyDrive/ift6759_trees/data/raw/RemoteSensing/RGB/OSBS_32.tif',
#  '/content/drive/MyDrive/ift6759_trees/data/raw/RemoteSensing/RGB/MLBS_20.tif',
#  '/content/drive/MyDrive/ift6759_trees/data/raw/RemoteSensing/RGB/MLBS_39.tif']

# %%
train
# Out:
# ['/content/drive/MyDrive/ift6759_trees/data/raw/RemoteSensing/RGB/MLBS_1.tif',
#  '/content/drive/MyDrive/ift6759_trees/data/raw/RemoteSensing/RGB/MLBS_10.tif',
#  '/content/drive/MyDrive/ift6759_trees/data/raw/RemoteSensing/RGB/MLBS_11.tif',
#  '/content/drive/MyDrive/ift6759_trees/data/raw/RemoteSensing/RGB/MLBS_12.tif',
#  '/content/drive/MyDrive/ift6759_trees/data/raw/RemoteSensing/RGB/MLBS_13.tif',
#  '/content/drive/MyDrive/ift6759_trees/data/raw/RemoteSensing/RGB/MLBS_15.tif',
#  '/content/drive/MyDrive/ift6759_trees/data/raw/RemoteSensing/RGB/MLBS_16.tif',
#  '/content/drive/MyDrive/ift6759_trees/data/raw/RemoteSensing/RGB/MLBS_17.tif',
#  '/content/drive/MyDrive/ift6759_trees/data/raw/RemoteSensing/RGB/MLBS_18.tif',
#  '/content/drive/MyDrive/ift6759_trees/data/raw/RemoteSensing/RGB/MLBS_19.tif',
#  '/content/drive/MyDrive/ift6759_trees/data/raw/RemoteSensing/RGB/MLBS_2.tif',
#  '/content/drive/MyDrive/ift6759_trees/data/raw/RemoteSensing/RGB/MLBS_21.tif',
#  '/content/drive/MyDrive/ift6759_trees/data/raw/RemoteSensing/RGB/MLBS_22.tif',
#  '/content/drive/MyDrive/ift6759_trees/data/raw/RemoteSensing/RGB/MLBS_23.tif',
#  '/content/drive/MyDrive/ift6759_trees/data/raw/RemoteSensing/RGB/MLBS_24.tif',
#  '/content/drive/MyDrive/ift6759_trees/data/raw/RemoteSensing/RGB/MLBS_26.tif',
#  '/content/drive/MyDrive/ift6759_trees/data/raw/RemoteSensing/RGB/MLBS_27.tif',
#  '/content/drive/MyDrive/ift6759_trees/data/raw/RemoteSensing/RGB/MLBS_28.tif',
#  '/content/drive/MyDrive/ift6759_trees/data/raw/RemoteSensing/RGB/MLBS_29.tif',
#  '/content/drive/MyDrive/ift6759_trees/data/raw/RemoteSensing/RGB/MLBS_3.tif',
#  '/content/drive/MyDrive/ift6759_trees/data/raw/RemoteSensing/RGB/MLBS_30.tif',
#  '/content/drive/MyDrive/ift6759_trees/data/raw/RemoteSensing/RGB/MLBS_31.tif',
#  '/content/drive/MyDrive/ift6759_trees/data/raw/RemoteSensing/RGB/MLBS_32.tif',
#  '/content/drive/MyDrive/ift6759_trees/data/raw/RemoteSensing/RGB/MLBS_33.tif',
#  '/content/drive/MyDrive/ift6759_trees/data/raw/RemoteSensing/RGB/MLBS_35.tif',
#  '/content/drive/MyDrive/ift6759_trees/data/raw/RemoteSensing/RGB/MLBS_36.tif',
#  '/content/drive/MyDrive/ift6759_trees/data/raw/RemoteSensing/RGB/MLBS_37.tif',
#  '/content/drive/MyDrive/ift6759_trees/data/raw/RemoteSensing/RGB/MLBS_38.tif',
#  '/content/drive/MyDrive/ift6759_trees/data/raw/RemoteSensing/RGB/MLBS_40.tif',
#  '/content/drive/MyDrive/ift6759_trees/data/raw/RemoteSensing/RGB/MLBS_41.tif',
#  '/content/drive/MyDrive/ift6759_trees/data/raw/RemoteSensing/RGB/MLBS_43.tif',
#  '/content/drive/MyDrive/ift6759_trees/data/raw/RemoteSensing/RGB/MLBS_45.tif',
#  '/content/drive/MyDrive/ift6759_trees/data/raw/RemoteSensing/RGB/MLBS_46.tif',
#  '/content/drive/MyDrive/ift6759_trees/data/raw/RemoteSensing/RGB/MLBS_5.tif',
#  '/content/drive/MyDrive/ift6759_trees/data/raw/RemoteSensing/RGB/MLBS_6.tif',
#  '/content/drive/MyDrive/ift6759_trees/data/raw/RemoteSensing/RGB/MLBS_7.tif',
#  '/content/drive/MyDrive/ift6759_trees/data/raw/RemoteSensing/RGB/MLBS_8.tif',
#  '/content/drive/MyDrive/ift6759_trees/data/raw/RemoteSensing/RGB/OSBS_1.tif',
#  '/content/drive/MyDrive/ift6759_trees/data/raw/RemoteSensing/RGB/OSBS_10.tif',
#  '/content/drive/MyDrive/ift6759_trees/data/raw/RemoteSensing/RGB/OSBS_11.tif',
#  '/content/drive/MyDrive/ift6759_trees/data/raw/RemoteSensing/RGB/OSBS_13.tif',
#  '/content/drive/MyDrive/ift6759_trees/data/raw/RemoteSensing/RGB/OSBS_15.tif',
#  '/content/drive/MyDrive/ift6759_trees/data/raw/RemoteSensing/RGB/OSBS_17.tif',
#  '/content/drive/MyDrive/ift6759_trees/data/raw/RemoteSensing/RGB/OSBS_18.tif',
#  '/content/drive/MyDrive/ift6759_trees/data/raw/RemoteSensing/RGB/OSBS_19.tif',
#  '/content/drive/MyDrive/ift6759_trees/data/raw/RemoteSensing/RGB/OSBS_2.tif',
#  '/content/drive/MyDrive/ift6759_trees/data/raw/RemoteSensing/RGB/OSBS_20.tif',
#  '/content/drive/MyDrive/ift6759_trees/data/raw/RemoteSensing/RGB/OSBS_21.tif',
#  '/content/drive/MyDrive/ift6759_trees/data/raw/RemoteSensing/RGB/OSBS_22.tif',
#  '/content/drive/MyDrive/ift6759_trees/data/raw/RemoteSensing/RGB/OSBS_25.tif',
#  '/content/drive/MyDrive/ift6759_trees/data/raw/RemoteSensing/RGB/OSBS_28.tif',
#  '/content/drive/MyDrive/ift6759_trees/data/raw/RemoteSensing/RGB/OSBS_29.tif',
#  '/content/drive/MyDrive/ift6759_trees/data/raw/RemoteSensing/RGB/OSBS_3.tif',
#  '/content/drive/MyDrive/ift6759_trees/data/raw/RemoteSensing/RGB/OSBS_30.tif',
#  '/content/drive/MyDrive/ift6759_trees/data/raw/RemoteSensing/RGB/OSBS_31.tif',
#  '/content/drive/MyDrive/ift6759_trees/data/raw/RemoteSensing/RGB/OSBS_33.tif',
#  '/content/drive/MyDrive/ift6759_trees/data/raw/RemoteSensing/RGB/OSBS_34.tif',
#  '/content/drive/MyDrive/ift6759_trees/data/raw/RemoteSensing/RGB/OSBS_36.tif',
#  '/content/drive/MyDrive/ift6759_trees/data/raw/RemoteSensing/RGB/OSBS_37.tif',
#  '/content/drive/MyDrive/ift6759_trees/data/raw/RemoteSensing/RGB/OSBS_38.tif',
#  '/content/drive/MyDrive/ift6759_trees/data/raw/RemoteSensing/RGB/OSBS_39.tif',
#  '/content/drive/MyDrive/ift6759_trees/data/raw/RemoteSensing/RGB/OSBS_4.tif',
#  '/content/drive/MyDrive/ift6759_trees/data/raw/RemoteSensing/RGB/OSBS_5.tif',
#  '/content/drive/MyDrive/ift6759_trees/data/raw/RemoteSensing/RGB/OSBS_6.tif',
#  '/content/drive/MyDrive/ift6759_trees/data/raw/RemoteSensing/RGB/OSBS_7.tif',
#  '/content/drive/MyDrive/ift6759_trees/data/raw/RemoteSensing/RGB/OSBS_8.tif',
#  '/content/drive/MyDrive/ift6759_trees/data/raw/RemoteSensing/RGB/OSBS_9.tif']

# %%
len(val), len(test), len(train)
# Out:
# (9, 9, 67)

# %%
# datatype: RGB, HSI, LAS, CHM
# '/content/drive/MyDrive/ift6759_trees/data/interim/RemoteSensing/train/{datatype}' 

os.makedirs('/content/drive/MyDrive/ift6759_trees/data/interim/RemoteSensing/train/RGB', exist_ok=True) 
os.makedirs('/content/drive/MyDrive/ift6759_trees/data/interim/RemoteSensing/val/RGB', exist_ok=True)
os.makedirs('/content/drive/MyDrive/ift6759_trees/data/interim/RemoteSensing/test/RGB', exist_ok=True)

# %%
import shutil
# subset: train, val, test
# '/content/drive/MyDrive/ift6759_trees/data/interim/RemoteSensing/{subset}/{datatype}' 

dst = '/content/drive/MyDrive/ift6759_trees/data/interim/RemoteSensing/test/CHM' 
for file in test: # train, val, test 
  filename = os.path.basename(file)
  dst_name = os.path.join(dst, filename)
  shutil.copy2(file, dst_name)

# %%
len(glob(os.path.join('/content/drive/MyDrive/ift6759_trees/data/interim/RemoteSensing/train/CHM', '*.tif')))
# Out:
# 67

# %% [markdown]
# ## Dataframe split

# %% [markdown]
# ### Explore ITC data

# %%
import geopandas

mlbs_shapefile_path = '/content/drive/MyDrive/ift6759_trees/data/raw/ITC/train_MLBS.shp'
osbs_shapefile_path = '/content/drive/MyDrive/ift6759_trees/data/raw/ITC/train_OSBS.shp'

mlbs = geopandas.read_file(mlbs_shapefile_path)
osbs = geopandas.read_file(osbs_shapefile_path)

# %%
mlbs
# Out:
#      id     indvdID                                           geometry
# 0    57   MLBS01681  POLYGON ((542071.187 4134996.073, 542071.187 4...
# 1    45   MLBS01679  POLYGON ((542055.000 4134998.793, 542058.995 4...
# 2    49   MLBS01674  POLYGON ((542060.170 4134993.382, 542060.170 4...
# 3    63   MLBS01678  POLYGON ((542057.702 4134991.627, 542057.702 4...
# 4    50   MLBS01675  POLYGON ((542061.068 4134991.193, 542061.068 4...
# ..   ..         ...                                                ...
# 703  89   MLBS01541  POLYGON ((541876.000 4135859.653, 541882.697 4...
# 704  84   MLBS01546  POLYGON ((541887.842 4135850.434, 541887.842 4...
# 705  86   MLBS01545  POLYGON ((541879.662 4135850.434, 541879.662 4...
# 706  90   MLBS01544  POLYGON ((541878.045 4135858.489, 541878.045 4...
# 707  91  MLBS01556A  POLYGON ((541882.109 4135868.242, 541882.109 4...
#
# [708 rows x 3 columns]

# %%
mlbs.centroid
# Out:
# 0      POINT (542073.078 4134997.537)
# 1      POINT (542056.998 4134996.584)
# 2      POINT (542062.569 4134995.518)
# 3      POINT (542059.395 4134993.537)
# 4      POINT (542065.323 4134994.135)
#                     ...
# 703    POINT (541879.349 4135856.111)
# 704    POINT (541891.754 4135853.556)
# 705    POINT (541882.208 4135852.440)
# 706    POINT (541882.365 4135861.620)
# 707    POINT (541886.563 4135869.121)
# Length: 708, dtype: geometry

# %%
mlbs["area"] = mlbs.area
mlbs["area"]
# Out:
# 0      11.071482
# 1      17.646278
# 2      20.504262
# 3      12.941551
# 4      50.078353
#          ...
# 703    47.438893
# 704    48.845377
# 705    20.424518
# 706    54.083553
# 707    15.667199
# Name: area, Length: 708, dtype: float64

# %%
mlbs.crs
# Out:
# <Derived Projected CRS: EPSG:32617>
# Name: WGS 84 / UTM zone 17N
# Axis Info [cartesian]:
# - E[east]: Easting (metre)
# - N[north]: Northing (metre)
# Area of Use:
# - name: Between 84°W and 78°W, northern hemisphere between equator and 84°N, onshore and offshore. Bahamas. Ecuador - north of equator. Canada - Nunavut; Ontario; Quebec. Cayman Islands. Colombia. Costa Rica. Cuba. Jamaica. Nicaragua. Panama. United States (USA).
# - bounds: (-84.0, 0.0, -78.0, 84.0)
# Coordinate Operation:
# - name: UTM zone 17N
# - method: Transverse Mercator
# Datum: World Geodetic System 1984 ensemble
# - Ellipsoid: WGS 84
# - Prime Meridian: Greenwich

# %%
mlbs.explore("area", legend=False)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_eaf9dfb91a2dad7a29c3466adf905b5c {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_eaf9dfb91a2dad7a29c3466adf905b5c&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_eaf9dfb91a2dad7a29c3466adf905b5c = L.map(
#                 &quot;map_eaf9dfb91a2dad7a29c3466adf905b5c&quot;,
#                 {
#                     center: [37.39488606428136, -80.530514262597],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_eaf9dfb91a2dad7a29c3466adf905b5c);
#
#
#
#
#
#             var tile_layer_4b1ea5c6e88a8809677cb14e434cd8ec = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_eaf9dfb91a2dad7a29c3466adf905b5c);
#
#
#             map_eaf9dfb91a2dad7a29c3466adf905b5c.fitBounds(
#                 [[37.35718310036205, -80.57193674352864], [37.43258902820067, -80.48909178166535]],
#                 {}
#             );
#
#
#         function geo_json_083a4eb0c7351d6426dc0eab26ecf065_styler(feature) {
#             switch(feature.id) {
#                 case &quot;0&quot;: case &quot;21&quot;: case &quot;92&quot;: case &quot;114&quot;: case &quot;117&quot;: case &quot;181&quot;: case &quot;281&quot;: case &quot;413&quot;: case &quot;436&quot;: case &quot;659&quot;: case &quot;667&quot;:
#                     return {&quot;color&quot;: &quot;#481a6c&quot;, &quot;fillColor&quot;: &quot;#481a6c&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;1&quot;: case &quot;100&quot;: case &quot;187&quot;: case &quot;202&quot;: case &quot;207&quot;: case &quot;297&quot;: case &quot;588&quot;:
#                     return {&quot;color&quot;: &quot;#482878&quot;, &quot;fillColor&quot;: &quot;#482878&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;2&quot;: case &quot;49&quot;: case &quot;99&quot;: case &quot;129&quot;: case &quot;190&quot;: case &quot;375&quot;: case &quot;516&quot;: case &quot;537&quot;: case &quot;554&quot;: case &quot;617&quot;: case &quot;632&quot;: case &quot;673&quot;: case &quot;686&quot;:
#                     return {&quot;color&quot;: &quot;#472f7d&quot;, &quot;fillColor&quot;: &quot;#472f7d&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;3&quot;: case &quot;158&quot;: case &quot;171&quot;: case &quot;226&quot;: case &quot;302&quot;: case &quot;309&quot;: case &quot;316&quot;: case &quot;395&quot;: case &quot;675&quot;:
#                     return {&quot;color&quot;: &quot;#481d6f&quot;, &quot;fillColor&quot;: &quot;#481d6f&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;4&quot;: case &quot;102&quot;: case &quot;239&quot;: case &quot;299&quot;:
#                     return {&quot;color&quot;: &quot;#306a8e&quot;, &quot;fillColor&quot;: &quot;#306a8e&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;5&quot;: case &quot;12&quot;: case &quot;22&quot;: case &quot;74&quot;: case &quot;303&quot;: case &quot;324&quot;: case &quot;388&quot;: case &quot;474&quot;: case &quot;482&quot;: case &quot;579&quot;: case &quot;636&quot;:
#                     return {&quot;color&quot;: &quot;#482173&quot;, &quot;fillColor&quot;: &quot;#482173&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;6&quot;: case &quot;56&quot;: case &quot;146&quot;: case &quot;182&quot;: case &quot;271&quot;: case &quot;310&quot;: case &quot;363&quot;: case &quot;420&quot;: case &quot;423&quot;: case &quot;523&quot;:
#                     return {&quot;color&quot;: &quot;#39558c&quot;, &quot;fillColor&quot;: &quot;#39558c&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;7&quot;: case &quot;140&quot;: case &quot;344&quot;: case &quot;512&quot;: case &quot;613&quot;: case &quot;674&quot;:
#                     return {&quot;color&quot;: &quot;#463480&quot;, &quot;fillColor&quot;: &quot;#463480&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;8&quot;: case &quot;36&quot;: case &quot;128&quot;: case &quot;477&quot;: case &quot;511&quot;: case &quot;672&quot;:
#                     return {&quot;color&quot;: &quot;#453581&quot;, &quot;fillColor&quot;: &quot;#453581&quo

# %% [markdown]
# ### Perform the split

# %%
df_mlbs = mlbs.geometry.bounds
df_mlbs['id'] = mlbs.id
df_mlbs['indvdID'] = mlbs.indvdID
df_mlbs
# Out:
#               minx          miny           maxx          maxy  id     indvdID
# 0    542071.186834  4.134996e+06  542074.969940  4.134999e+06  57   MLBS01681
# 1    542055.000000  4.134994e+06  542058.995294  4.134999e+06  45   MLBS01679
# 2    542060.169555  4.134993e+06  542064.969398  4.134998e+06  49   MLBS01674
# 3    542057.701672  4.134992e+06  542061.088781  4.134995e+06  63   MLBS01678
# 4    542061.068128  4.134991e+06  542069.577248  4.134997e+06  50   MLBS01675
# ..             ...           ...            ...           ...  ..         ...
# 703  541876.000000  4.135853e+06  541882.697322  4.135860e+06  89   MLBS01541
# 704  541887.841995  4.135850e+06  541895.666267  4.135857e+06  84   MLBS01546
# 705  541879.662196  4.135850e+06  541884.753120  4.135854e+06  86   MLBS01545
# 706  541878.045215  4.135858e+06  541886.683785  4.135865e+06  90   MLBS01544
# 707  541882.108654  4.135868e+06  541891.018121  4.135870e+06  91  MLBS01556A
#
# [708 rows x 6 columns]

# %%
df_osbs = osbs.geometry.bounds
df_osbs['id'] = osbs.id
df_osbs['indvdID'] = osbs.indvdID
df_osbs
# Out:
#           minx        miny       maxx        maxy    id    indvdID
# 0    404040.79  3284950.20  404042.98  3284953.62  1307  OSBS00044
# 1    404027.21  3284943.45  404035.20  3284951.43  1308  OSBS00120
# 2    404040.80  3284955.07  404042.98  3284960.53  1304  OSBS00123
# 3    404034.37  3284954.08  404040.75  3284960.17  1305  OSBS00122
# 4    404031.89  3284957.13  404033.64  3284958.74  1306  OSBS00121
# ..         ...         ...        ...         ...   ...        ...
# 467  404886.40  3284465.00  404893.92  3284466.11  1037  OSBS00849
# 468  404899.07  3284467.63  404906.00  3284475.69  1034  OSBS00910
# 469  404891.84  3284470.99  404899.85  3284477.62  1032  OSBS07977
# 470  404891.74  3284466.87  404899.05  3284472.04  1035  OSBS00898
# 471  404886.38  3284468.93  404891.71  3284478.53  1033  OSBS00881
#
# [472 rows x 6 columns]

# %%
df_all = pd.concat([df_mlbs, df_osbs], ignore_index=True, axis=0)
df_all
# Out:
#                minx          miny           maxx          maxy    id  \
# 0     542071.186834  4.134996e+06  542074.969940  4.134999e+06    57
# 1     542055.000000  4.134994e+06  542058.995294  4.134999e+06    45
# 2     542060.169555  4.134993e+06  542064.969398  4.134998e+06    49
# 3     542057.701672  4.134992e+06  542061.088781  4.134995e+06    63
# 4     542061.068128  4.134991e+06  542069.577248  4.134997e+06    50
# ...             ...           ...            ...           ...   ...
# 1175  404886.400000  3.284465e+06  404893.920000  3.284466e+06  1037
# 1176  404899.070000  3.284468e+06  404906.000000  3.284476e+06  1034
# 1177  404891.840000  3.284471e+06  404899.850000  3.284478e+06  1032
# 1178  404891.740000  3.284467e+06  404899.050000  3.284472e+06  1035
# 1179  404886.380000  3.284469e+06  404891.710000  3.284479e+06  1033
#
#         indvdID
# 0     MLBS01681
# 1     MLBS01679
# 2     MLBS01674
# 3     MLBS01678
# 4     MLBS01675
# ...         ...
# 1175  OSBS00849
# 1176  OSBS00910
# 1177  OSBS07977
# 1178  OSBS00898
# 1179  OSBS00881
#
# [1180 rows x 6 columns]

# %%
import pandas as pd

df = pd.read_csv('/content/drive/MyDrive/ift6759_trees/data/raw/Field/itc_rsFile.csv')
df
# Out:
#         id    indvdID      rsFile
# 0       57  MLBS01681  MLBS_1.tif
# 1       45  MLBS01679  MLBS_1.tif
# 2       49  MLBS01674  MLBS_1.tif
# 3       63  MLBS01678  MLBS_1.tif
# 4       50  MLBS01675  MLBS_1.tif
# ...    ...        ...         ...
# 1175  1037  OSBS00849  OSBS_9.tif
# 1176  1034  OSBS00910  OSBS_9.tif
# 1177  1032  OSBS07977  OSBS_9.tif
# 1178  1035  OSBS00898  OSBS_9.tif
# 1179  1033  OSBS00881  OSBS_9.tif
#
# [1180 rows x 3 columns]

# %%
df_1 = pd.read_csv('/content/drive/MyDrive/ift6759_trees/data/raw/Field/train_data.csv')
df_1
# Out:
#         indvdID siteID taxonID                  scientificName taxonRank  \
# 0     MLBS00797   MLBS    ACPE           Acer pensylvanicum L.   species
# 1     MLBS01563   MLBS    ACPE           Acer pensylvanicum L.   species
# 2     MLBS01628   MLBS    ACPE           Acer pensylvanicum L.   species
# 3     MLBS01682   MLBS    ACPE           Acer pensylvanicum L.   species
# 4     MLBS01675   MLBS    ACPE           Acer pensylvanicum L.   species
# ...         ...    ...     ...                             ...       ...
# 1161  MLBS01290   MLBS    ROPS         Robinia pseudoacacia L.   species
# 1162  MLBS01395   MLBS    TSCA  Tsuga canadensis (L.) Carriere   species
# 1163  MLBS01324   MLBS    TSCA  Tsuga canadensis (L.) Carriere   species
# 1164  MLBS01927   MLBS    TSCA  Tsuga canadensis (L.) Carriere   species
# 1165  MLBS02402   MLBS    TSCA  Tsuga canadensis (L.) Carriere   species
#
#      utmZone        nlcdClass  elevation        growthForm  \
# 0        17N  deciduousForest    1172.84  single bole tree
# 1        17N  deciduousForest    1221.21  single bole tree
# 2        17N  deciduousForest    1310.19  single bole tree
# 3        17N  deciduousForest    1267.66  single bole tree
# 4        17N  deciduousForest    1310.19  single bole tree
# ...      ...              ...        ...               ...
# 1161     17N  deciduousForest    1169.25  single bole tree
# 1162     17N  deciduousForest    1173.32  single bole tree
# 1163     17N  deciduousForest    1169.25  single bole tree
# 1164     17N  deciduousForest     794.50   multi-bole tree
# 1165     17N  deciduousForest     791.31  single bole tree
#
#                    plantStatus  stemDiameter  height  maxCrownDiameter  \
# 0                         Live          12.4    12.2               NaN
# 1        Live, disease damaged          12.3     6.7               4.5
# 2     Live, physically damaged          13.9     6.5               6.1
# 3                         Live          19.8    11.5               6.3
# 4                         Live          22.8     8.4               8.2
# ...                        ...           ...     ...               ...
# 1161                      Live          37.9    20.9               NaN
# 1162                      Live          27.4    11.6               NaN
# 1163                      Live          23.0    11.1               NaN
# 1164      Live, insect damaged          19.1    12.3               9.7
# 1165      Live, insect damaged          38.4    26.7               8.5
#
#       ninetyCrownDiameter    canopyPosition
# 0                     NaN               NaN
# 1                     4.4     Mostly shaded
# 2                     3.6     Mostly shaded
# 3                     6.0  Partially shaded
# 4                     6.4     Mostly shaded
# ...                   ...               ...
# 1161                  NaN               NaN
# 1162                  NaN               NaN
# 1163                  NaN               NaN
# 1164                  8.4     Mostly shaded
# 1165                  5.4     Mostly shaded
#
# [1166 rows x 15 columns]

# %%
df_all['rsFile'] = df['rsFile']
df_all
# Out:
#                minx          miny           maxx          maxy    id  \
# 0     542071.186834  4.134996e+06  542074.969940  4.134999e+06    57
# 1     542055.000000  4.134994e+06  542058.995294  4.134999e+06    45
# 2     542060.169555  4.134993e+06  542064.969398  4.134998e+06    49
# 3     542057.701672  4.134992e+06  542061.088781  4.134995e+06    63
# 4     542061.068128  4.134991e+06  542069.577248  4.134997e+06    50
# ...             ...           ...            ...           ...   ...
# 1175  404886.400000  3.284465e+06  404893.920000  3.284466e+06  1037
# 1176  404899.070000  3.284468e+06  404906.000000  3.284476e+06  1034
# 1177  404891.840000  3.284471e+06  404899.850000  3.284478e+06  1032
# 1178  404891.740000  3.284467e+06  404899.050000  3.284472e+06  1035
# 1179  404886.380000  3.284469e+06  404891.710000  3.284479e+06  1033
#
#         indvdID      rsFile
# 0     MLBS01681  MLBS_1.tif
# 1     MLBS01679  MLBS_1.tif
# 2     MLBS01674  MLBS_1.tif
# 3     MLBS01678  MLBS_1.tif
# 4     MLBS01675  MLBS_1.tif
# ...         ...         ...
# 1175  OSBS00849  OSBS_9.tif
# 1176  OSBS00910  OSBS_9.tif
# 1177  OSBS07977  OSBS_9.tif
# 1178  OSBS00898  OSBS_9.tif
# 1179  OSBS00881  OSBS_9.tif
#
# [1180 rows x 7 columns]

# %%
df_all.to_csv('/content/drive/MyDrive/ift6759_trees/data/raw/ITC/train_all.csv', index=False)

# %%
import pandas as pd

pd.read_csv('/content/drive/MyDrive/ift6759_trees/data/raw/ITC/train_all.csv')
# Out:
#                minx          miny           maxx          maxy    id  \
# 0     542071.186834  4.134996e+06  542074.969940  4.134999e+06    57
# 1     542055.000000  4.134994e+06  542058.995294  4.134999e+06    45
# 2     542060.169555  4.134993e+06  542064.969398  4.134998e+06    49
# 3     542057.701672  4.134992e+06  542061.088781  4.134995e+06    63
# 4     542061.068128  4.134991e+06  542069.577248  4.134997e+06    50
# ...             ...           ...            ...           ...   ...
# 1175  404886.400000  3.284465e+06  404893.920000  3.284466e+06  1037
# 1176  404899.070000  3.284468e+06  404906.000000  3.284476e+06  1034
# 1177  404891.840000  3.284471e+06  404899.850000  3.284478e+06  1032
# 1178  404891.740000  3.284467e+06  404899.050000  3.284472e+06  1035
# 1179  404886.380000  3.284469e+06  404891.710000  3.284479e+06  1033
#
#         indvdID      rsFile
# 0     MLBS01681  MLBS_1.tif
# 1     MLBS01679  MLBS_1.tif
# 2     MLBS01674  MLBS_1.tif
# 3     MLBS01678  MLBS_1.tif
# 4     MLBS01675  MLBS_1.tif
# ...         ...         ...
# 1175  OSBS00849  OSBS_9.tif
# 1176  OSBS00910  OSBS_9.tif
# 1177  OSBS07977  OSBS_9.tif
# 1178  OSBS00898  OSBS_9.tif
# 1179  OSBS00881  OSBS_9.tif
#
# [1180 rows x 7 columns]

# %%
train_files = os.listdir('/content/drive/MyDrive/ift6759_trees/data/interim/RemoteSensing/train/RGB')
val_files = os.listdir('/content/drive/MyDrive/ift6759_trees/data/interim/RemoteSensing/val/RGB')
test_files = os.listdir('/content/drive/MyDrive/ift6759_trees/data/interim/RemoteSensing/test/RGB')

# %%
df_train = df_all.loc[df_all['rsFile'].isin(train_files)]
df_train.to_csv('/content/drive/MyDrive/ift6759_trees/data/interim/ITC/train.csv', index=False)
df_train
# Out:
#                minx          miny           maxx          maxy    id  \
# 0     542071.186834  4.134996e+06  542074.969940  4.134999e+06    57
# 1     542055.000000  4.134994e+06  542058.995294  4.134999e+06    45
# 2     542060.169555  4.134993e+06  542064.969398  4.134998e+06    49
# 3     542057.701672  4.134992e+06  542061.088781  4.134995e+06    63
# 4     542061.068128  4.134991e+06  542069.577248  4.134997e+06    50
# ...             ...           ...            ...           ...   ...
# 1175  404886.400000  3.284465e+06  404893.920000  3.284466e+06  1037
# 1176  404899.070000  3.284468e+06  404906.000000  3.284476e+06  1034
# 1177  404891.840000  3.284471e+06  404899.850000  3.284478e+06  1032
# 1178  404891.740000  3.284467e+06  404899.050000  3.284472e+06  1035
# 1179  404886.380000  3.284469e+06  404891.710000  3.284479e+06  1033
#
#         indvdID      rsFile
# 0     MLBS01681  MLBS_1.tif
# 1     MLBS01679  MLBS_1.tif
# 2     MLBS01674  MLBS_1.tif
# 3     MLBS01678  MLBS_1.tif
# 4     MLBS01675  MLBS_1.tif
# ...         ...         ...
# 1175  OSBS00849  OSBS_9.tif
# 1176  OSBS00910  OSBS_9.tif
# 1177  OSBS07977  OSBS_9.tif
# 1178  OSBS00898  OSBS_9.tif
# 1179  OSBS00881  OSBS_9.tif
#
# [931 rows x 7 columns]

# %%
df_val = df_all.loc[df_all['rsFile'].isin(val_files)]
df_val.to_csv('/content/drive/MyDrive/ift6759_trees/data/interim/ITC/val.csv', index=False)
df_val
# Out:
#                minx          miny           maxx          maxy    id  \
# 78    544326.548574  4.142345e+06  544328.880060  4.142351e+06   186
# 79    544322.797261  4.142348e+06  544328.880060  4.142358e+06   690
# 80    544323.731048  4.142338e+06  544328.880060  4.142344e+06   187
# 81    544317.518985  4.142339e+06  544323.731048  4.142346e+06   188
# 82    544321.472116  4.142338e+06  544327.684179  4.142339e+06   189
# ...             ...           ...            ...           ...   ...
# 970   406967.630000  3.283961e+06  406969.870000  3.283964e+06  1497
# 971   406969.510000  3.283959e+06  406973.340000  3.283962e+06  1496
# 972   406965.340000  3.283961e+06  406967.420000  3.283962e+06  1498
# 1077  404685.570000  3.288445e+06  404691.780000  3.288453e+06  1303
# 1079  404680.000000  3.288435e+06  404692.300000  3.288450e+06  1302
#
#         indvdID       rsFile
# 78    MLBS01793  MLBS_14.tif
# 79    MLBS01798  MLBS_14.tif
# 80    MLBS01789  MLBS_14.tif
# 81    MLBS01781  MLBS_14.tif
# 82    MLBS01785  MLBS_14.tif
# ...         ...          ...
# 970   OSBS00011  OSBS_27.tif
# 971   OSBS01298  OSBS_27.tif
# 972   OSBS01268  OSBS_27.tif
# 1077  OSBS01121  OSBS_16.tif
# 1079  OSBS01120  OSBS_16.tif
#
# [115 rows x 7 columns]

# %%
df_test = df_all.loc[df_all['rsFile'].isin(test_files)]
df_test.to_csv('/content/drive/MyDrive/ift6759_trees/data/interim/ITC/test.csv', index=False)
df_test
# Out:
#                minx          miny           maxx          maxy    id  \
# 191   538213.057073  4.140953e+06  538219.171177  4.140956e+06   273
# 192   538206.014245  4.140955e+06  538212.979679  4.140963e+06   275
# 193   538211.199624  4.140954e+06  538215.224097  4.140958e+06   274
# 194   538210.425687  4.140958e+06  538218.397240  4.140968e+06   272
# 195   538213.515745  4.140954e+06  538223.000000  4.140966e+06   280
# ...             ...           ...            ...           ...   ...
# 1050  408346.700000  3.285353e+06  408352.000000  3.285358e+06  1408
# 1051  408351.550000  3.285366e+06  408352.000000  3.285367e+06  1403
# 1052  408344.920000  3.285369e+06  408351.290000  3.285373e+06  1399
# 1078  404685.570000  3.288445e+06  404691.780000  3.288453e+06  1303
# 1080  404680.000000  3.288435e+06  404692.300000  3.288450e+06  1302
#
#         indvdID       rsFile
# 191   MLBS02427  MLBS_20.tif
# 192   MLBS02421  MLBS_20.tif
# 193   MLBS02423  MLBS_20.tif
# 194   MLBS02419  MLBS_20.tif
# 195   MLBS02417  MLBS_20.tif
# ...         ...          ...
# 1050  OSBS00006  OSBS_32.tif
# 1051  OSBS00005  OSBS_32.tif
# 1052  OSBS00004  OSBS_32.tif
# 1078  OSBS01121  OSBS_35.tif
# 1080  OSBS01120  OSBS_35.tif
#
# [134 rows x 7 columns]

# %%
df_train = pd.read_csv('/content/drive/MyDrive/ift6759_trees/data/interim/ITC/train.csv')
df_train.rsFile.unique()
# Out:
# array(['MLBS_1.tif', 'MLBS_10.tif', 'MLBS_11.tif', 'MLBS_12.tif',
#        'MLBS_13.tif', 'MLBS_15.tif', 'MLBS_16.tif', 'MLBS_17.tif',
#        'MLBS_18.tif', 'MLBS_19.tif', 'MLBS_2.tif', 'MLBS_21.tif',
#        'MLBS_22.tif', 'MLBS_23.tif', 'MLBS_24.tif', 'MLBS_26.tif',
#        'MLBS_27.tif', 'MLBS_28.tif', 'MLBS_29.tif', 'MLBS_3.tif',
#        'MLBS_30.tif', 'MLBS_31.tif', 'MLBS_32.tif', 'MLBS_33.tif',
#        'MLBS_35.tif', 'MLBS_36.tif', 'MLBS_37.tif', 'MLBS_38.tif',
#        'MLBS_40.tif', 'MLBS_41.tif', 'MLBS_43.tif', 'MLBS_45.tif',
#        'MLBS_46.tif', 'MLBS_5.tif', 'MLBS_6.tif', 'MLBS_8.tif',
#        'OSBS_1.tif', 'OSBS_10.tif', 'OSBS_11.tif', 'OSBS_13.tif',
#        'OSBS_15.tif', 'OSBS_17.tif', 'OSBS_18.tif', 'OSBS_19.tif',
#        'OSBS_2.tif', 'OSBS_20.tif', 'OSBS_21.tif', 'OSBS_22.tif',
#        'OSBS_25.tif', 'OSBS_28.tif', 'OSBS_29.tif', 'OSBS_3.tif',
#        'OSBS_30.tif', 'OSBS_31.tif', 'OSBS_33.tif', 'OSBS_34.tif',
#        'OSBS_36.tif', 'OSBS_37.tif', 'OSBS_38.tif', 'OSBS_39.tif',
#        'OSBS_4.tif', 'OSBS_5.tif', 'OSBS_6.tif', 'OSBS_7.tif',
#        'OSBS_8.tif', 'OSBS_9.tif'], dtype=object)

# %%
df_val = pd.read_csv('/content/drive/MyDrive/ift6759_trees/data/interim/ITC/val.csv')
len(df_val.rsFile.unique())
# Out:
# 9

# %%
df_test = pd.read_csv('/content/drive/MyDrive/ift6759_trees/data/interim/ITC/test.csv')
len(df_test.rsFile.unique())
# Out:
# 9
